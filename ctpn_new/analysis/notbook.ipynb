# %%
import pandas
import pickle
import os

# %%
with open('./features.pkl', 'rb') as fid:        
    d = pickle.load(fid)
data = pandas.DataFrame(d)
data.describe()
# Out:
#                 area   below_width  horizon_inclination   left_height  \
# count   18871.000000  18871.000000         18871.000000  18871.000000
# mean     4672.282338     81.870489             0.186402     25.875841
# std     12200.689150    132.527109             0.902383     43.843206
# min         0.000000   -973.000000             0.000000   -307.000000
# 25%       272.000000     15.000000             0.050000      8.000000
# 50%      1059.000000     47.000000             0.100000     17.000000
# 75%      4477.500000    122.000000             0.200000     37.000000
# max    588682.000000   2055.000000            99.300000   1772.000000
#
#        right_height      up_width  vertical_inclination
# count  18871.000000  18871.000000          18871.000000
# mean      25.789836     81.873881              0.119813
# std       43.659101    132.383589              0.300419
# min     -303.000000   -995.000000              0.000000
# ...
